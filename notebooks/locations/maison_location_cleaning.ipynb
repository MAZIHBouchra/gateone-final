# %% [markdown]
# # Data Cleaning Perfect - Maison Location Marrakech
# This notebook implements the 'Perfect Cleaning' pipeline for Machine Learning preparation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# File path
file_path = '../../data/marrakech_immo_location/maison_location.csv'

# Load data
if os.path.exists(file_path):
    df = pd.read_csv(file_path)
    print(f"Successfully loaded {file_path}")
    print(f"Initial shape: {df.shape}")
    display(df.head())
else:
    print(f"ERROR: File not found at {file_path}")
# Out:
# Successfully loaded ../../data/marrakech_immo_location/maison_location.csv
# Initial shape: (487, 34)
#         id                                              titre  \
# 0    70368  Maison à louer 3 000 dh 100 m², 3 chambres - B...
# 1   706875  Maison à louer 5 000 dh 150 m², 2 chambres - M...
# 2  2770209  Villa d’Exception à Bab Atlas – Fusion Archite...
# 3  2770204  Élégance Classique à la Palmeraie – Parc d'un ...
# 4  2770181  Signature Contemporaine au Golf Amelkis – Fini...
#
#                       prix                     localisation type_bien surface  \
# 0          3 000 DH / mois            Marrakech - Bouaakkaz    Maison     100
# 1          5 000 DH / mois               Marrakech - Mhamid    Maison     150
# 2  3,500,000€ 37,835,000Dh  Marrakech, Palmeraie, Bab Atlas    maison  1000.0
# 3  2,800,000€ 30,268,000Dh             Marrakech, Palmeraie    maison   850.0
# 4                      NaN        Marrakech, Golfs, Amelkis    maison  1200.0
#
#   chambres salles_bain description      agence  ... etage surface_terrain  \
# 0        3           1         NaN         NaN  ...    -1             NaN
# 1        2           1         NaN         NaN  ...    -1             NaN
# 2      6.0         NaN         NaN  Immo Maroc  ...    -1             NaN
# 3      6.0         NaN         NaN  Immo Maroc  ...    -1             NaN
# 4      5.0         NaN         NaN  Immo Maroc  ...    -1             NaN
#
#    prix_num  surface_num  chambres_num  salles_bain_num  nb_pieces   quartier  \
# 0    3000.0        100.0           3.0              1.0        5.0      Autre
# 1    5000.0        150.0           2.0              1.0        4.0    M'hamid
# 2       NaN       1000.0           6.0              0.0        7.0  Palmeraie
# 3       NaN        850.0           6.0              0.0        7.0  Palmeraie
# 4       NaN       1200.0           5.0              0.0        6.0      Autre
#
#      prix_m2  prix_m2_median_quartier
# 0  30.000000                66.985294
# 1  33.333333                33.333333
# 2        NaN                      NaN
# 3        NaN                      NaN
# 4        NaN                      NaN
#
# [5 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 487 entries, 0 to 486
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       350 non-null    str
#  1   titre                    487 non-null    str
#  2   prix                     455 non-null    str
#  3   localisation             487 non-null    str
#  4   type_bien                487 non-null    str
#  5   surface                  468 non-null    str
#  6   chambres                 476 non-null    str
#  7   salles_bain              181 non-null    str
#  8   description              199 non-null    str
#  9   agence                   350 non-null    str
#  10  url                      487 non-null    str
#  11  source                   487 non-null    str
#  12  piscine                  487 non-null    int64
#  13  parking                  487 non-null    int64
#  14  ascenseur                487 non-null    int64
#  15  terrasse                 487 non-null    int64
#  16  jardin                   487 non-null    int64
#  17  climatisation            487 non-null    int64
#  18  securite                 487 non-null    int64
#  19  vue                      487 non-null    int64
#  20  meuble                   487 non-null    int64
#  21  neuf                     487 non-null    int64
#  22  cave                     487 non-null    int64
#  23  hammam                   487 non-null    int64
#  24  etage                    487 non-null    int64
#  25  surface_terrain          0 non-null      float64
#  26  prix_num                 153 non-null    float64
#  27  surface_num              466 non-null    float64
#  28  chambres_num             487 non-null    float64
#  29  salles_bain_num          487 non-null    float64
#  30  nb_pieces                487 non-null    float64
#  31  quartier                 487 non-null    str
#  32  prix_m2                  143 non-null    float64
#  33  prix_m2_median_quartier  193 non-null    float64
# dtypes: float64(8), int64(13), str(13)
# memory usage: 129.5 KB

# %%
df.describe()
# Out:
#           piscine     parking   ascenseur    terrasse      jardin  \
# count  487.000000  487.000000  487.000000  487.000000  487.000000
# mean     0.168378    0.032854    0.004107    0.098563    0.172485
# std      0.374586    0.178438    0.064018    0.298380    0.378190
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000
#
#        climatisation    securite         vue      meuble        neuf  ...  \
# count     487.000000  487.000000  487.000000  487.000000  487.000000  ...
# mean        0.034908    0.016427    0.051335    0.145791    0.028747  ...
# std         0.183735    0.127242    0.220906    0.353259    0.167268  ...
# min         0.000000    0.000000    0.000000    0.000000    0.000000  ...
# 25%         0.000000    0.000000    0.000000    0.000000    0.000000  ...
# 50%         0.000000    0.000000    0.000000    0.000000    0.000000  ...
# 75%         0.000000    0.000000    0.000000    0.000000    0.000000  ...
# max         1.000000    1.000000    1.000000    1.000000    1.000000  ...
#
#            hammam       etage  surface_terrain      prix_num   surface_num  \
# count  487.000000  487.000000              0.0  1.530000e+02    466.000000
# mean     0.022587   -0.905544              NaN  2.685611e+04    600.148069
# std      0.148736    0.367550              NaN  1.232283e+05    893.482146
# min      0.000000   -1.000000              NaN  6.000000e+00      0.000000
# 25%      0.000000   -1.000000              NaN  4.000000e+03    145.000000
# 50%      0.000000   -1.000000              NaN  1.100000e+04    420.000000
# 75%      0.000000   -1.000000              NaN  2.400000e+04    750.000000
# max      1.000000    2.000000              NaN  1.515000e+06  11200.000000
#
#        chambres_num  salles_bain_num   nb_pieces      prix_m2  \
# count    487.000000       487.000000  487.000000   143.000000
# mean       4.572895         0.743326    6.283368   107.711679
# std        2.808410         1.241362    2.814898   283.508883
# min        0.000000         0.000000    1.000000     1.339286
# 25%        3.000000         0.000000    5.000000    30.000000
# 50%        4.000000         0.000000    6.000000    50.000000
# 75%        5.000000         1.000000    7.000000   100.000000
# max       24.000000         6.000000   25.000000  2500.000000
#
#        prix_m2_median_quartier
# count               193.000000
# mean                 52.163479
# std                  20.021902
# min                   9.259259
# 25%                  40.909091
# 50%                  40.909091
# 75%                  68.181818
# max                 118.750000
#
# [8 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['id', 'titre', 'prix', 'localisation', 'type_bien', 'surface',
#        'chambres', 'salles_bain', 'description', 'agence', 'url', 'source',
#        'piscine', 'parking', 'ascenseur', 'terrasse', 'jardin',
#        'climatisation', 'securite', 'vue', 'meuble', 'neuf', 'cave', 'hammam',
#        'etage', 'surface_terrain', 'prix_num', 'surface_num', 'chambres_num',
#        'salles_bain_num', 'nb_pieces', 'quartier', 'prix_m2',
#        'prix_m2_median_quartier'],
#       dtype='str')

# %%
df.shape
# Out:
# (487, 34)

# %% [markdown]
# ## 1. Target Protection & Deduplication
# We must drop rows without a price (target) and remove duplicates.

# %%
if 'df' in locals():
    # 1. Drop missing target
    if 'prix_num' in df.columns:
        initial_len = len(df)
        df = df.dropna(subset=['prix_num'])
        print(f"Dropped {initial_len - len(df)} rows with missing prix_num")
    
    # 2. Drop duplicates
    initial_len = len(df)
    df = df.drop_duplicates()
    print(f"Dropped {initial_len - len(df)} duplicate rows")
# Out:
# Dropped 334 rows with missing prix_num
# Dropped 0 duplicate rows

# %% [markdown]
# ## 2. Feature Selection & Data Leakage Prevention
# Drop non-predictive columns and columns that cause data leakage (like prix_m2).

# %%
if 'df' in locals():
    cols_to_drop = ['id', 'url', 'source', 'titre', 'description', 'prix', 'surface', 'localisation', 'chambres', 'salles_bain', 'surface_terrain']
    existing_drops = [c for c in cols_to_drop if c in df.columns]
    df = df.drop(columns=existing_drops)
    print(f"Dropped columns: {existing_drops}")
    print(f"Remaining columns: {df.columns.tolist()}")
# Out:
# Dropped columns: ['id', 'url', 'source', 'titre', 'description', 'prix', 'surface', 'localisation', 'chambres', 'salles_bain', 'surface_terrain']
# Remaining columns: ['type_bien', 'agence', 'piscine', 'parking', 'ascenseur', 'terrasse', 'jardin', 'climatisation', 'securite', 'vue', 'meuble', 'neuf', 'cave', 'hammam', 'etage', 'prix_num', 'surface_num', 'chambres_num', 'salles_bain_num', 'nb_pieces', 'quartier', 'prix_m2', 'prix_m2_median_quartier']

# %% [markdown]
# ## 3. Intelligent Imputation
# Handling missing values for features.

# %%
if 'df' in locals():
    # Missing values before
    print("Missing values before imputation:")
    print(df.isnull().sum()[df.isnull().sum() > 0])
    
    # 1. Numeric: Median
    if 'surface_num' in df.columns:
        df['surface_num'] = df['surface_num'].fillna(df['surface_num'].median())
    
   
    # 2. Rooms/Baths logic - Imputation par la moyenne au lieu de 0.0
for col in ['chambres_num', 'salles_bain_num']:
    if col in df.columns:
        # On remplace les 0 par NaN pour qu'ils soient imputés par la moyenne
        df[col] = df[col].replace(0, np.nan)
        # Remplissage par la moyenne (arrondie à l'entier le plus proche)
        df[col] = df[col].fillna(round(df[col].mean() if not df[col].isnull().all() else 1))


# 1b. Calcul du prix_m2 manquant à partir du prix_num et surface_num
if 'prix_m2' in df.columns and 'prix_num' in df.columns and 'surface_num' in df.columns:
    # On remplace temporairement les surfaces 0 par NaN pour éviter la division par zéro
    temp_surface = df['surface_num'].replace(0, np.nan)
    df['prix_m2'] = df['prix_m2'].fillna(df['prix_num'] / temp_surface)
  
    # 3. Categorical: Mode
    cat_cols = ['agence', 'type_bien', 'quartier']
    for col in cat_cols:
        if col in df.columns:
            df[col] = df[col].fillna(df[col].mode()[0] if not df[col].mode().empty else 'Inconnu')

    print("\nMissing values after imputation:")
    print(df.isnull().sum()[df.isnull().sum() > 0])
# Out:
# Missing values before imputation:
# agence                     89
# surface_num                 9
# prix_m2                    10
# prix_m2_median_quartier     6
# dtype: int64
#
# Missing values after imputation:
# prix_m2                    1
# prix_m2_median_quartier    6
# dtype: int64

# %%
df.shape
# Out:
# (153, 23)

# %% [markdown]
# ## 4. Feature Engineering
# Applying log transformations to stabilize variance.

# %%
if 'df' in locals():
    if 'prix_num' in df.columns:
        df['log_prix_num'] = np.log1p(df['prix_num'])
        print("Created log_prix_num")
    
    if 'surface_num' in df.columns:
        df['log_surface_num'] = np.log1p(df['surface_num'])
        print("Created log_surface_num")
# Out:
# Created log_prix_num
# Created log_surface_num

# %% [markdown]
# ## 5. Outlier Detection & Removal
# Using 1st and 99th percentiles.

# %%
if 'df' in locals():
    for col in ['prix_num', 'surface_num']:
        if col in df.columns:
            q_low = df[col].quantile(0.01)
            q_hi  = df[col].quantile(0.99)
            df = df[(df[col] <= q_hi) & (df[col] >= q_low)]
            print(f"Filtered {col} between {q_low:.2f} and {q_hi:.2f}")
    
    print(f"Final shape: {df.shape}")
# Out:
# Filtered prix_num between 200.00 and 163600.00
# Filtered surface_num between 40.00 and 4999.51
# Final shape: (147, 25)

# %% [markdown]
# ## 6. Exporting ML-Ready Data

# %%
if 'df' in locals():
    output_dir = '../../data/cleaned_data/location'
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    output_path = os.path.join(output_dir, 'maison_location_cleaned.csv')
    df.to_csv(output_path, index=False)
    print(f"Success! ML-ready data saved to {output_path}")
# Out:
# Success! ML-ready data saved to ../../data/cleaned_data/location/maison_location_cleaned.csv
