# %% [markdown]
# # Data Cleaning Perfect - Riad Location Marrakech
# This notebook implements the 'Perfect Cleaning' pipeline for Machine Learning preparation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# File path
file_path = '../../data/marrakech_immo_location/riad_location.csv'

# Load data
if os.path.exists(file_path):
    df = pd.read_csv(file_path)
    print(f"Successfully loaded {file_path}")
    print(f"Initial shape: {df.shape}")
    display(df.head())
else:
    print(f"ERROR: File not found at {file_path}")
# Out:
# Successfully loaded ../../data/marrakech_immo_location/riad_location.csv
# Initial shape: (152, 34)
#         id                                              titre  \
# 0  no-id-0                             Propriété à Sidi Abbad
# 1  no-id-1       Propriété à Route De L'Ourika - Canal Zaraba
# 2   RLD224  Charmant petit pied à terre rénové à louer en ...
# 3   RLD226  Riad de 2 chambres à louer dans excellent quar...
# 4   RLD225  A louer : élégant Riad rénové de 4 suites avec...
#
#                 prix                                 localisation  \
# 0          13 000 DH                        Sidi Abbad, Marrakech
# 1          30 000 DH  Route De L'Ourika - Canal Zaraba, Marrakech
# 2   3 600 Dhs / mois                                    Marrakech
# 3   9 000 Dhs / mois                                    Marrakech
# 4  22 000 Dhs / mois                                    Marrakech
#
#      type_bien surface chambres salles_bain  \
# 0  Appartement  120 m²        2           1
# 1  Appartement  355 m²       10          12
# 2         Riad   35 m²      NaN         NaN
# 3         Riad   NC m²      2.0         NaN
# 4         Riad   NC m²      NaN         NaN
#
#                                          description            agence  ...  \
# 0                                                NaN            Yakeey  ...
# 1                                                NaN            Yakeey  ...
# 2  Ce bien est situé dans le quartier le plus rec...  Marrakech Realty  ...
# 3  Ce bien est idéalement situé dans le quartier ...  Marrakech Realty  ...
# 4  Ce bien est situé dans un authentique quartier...  Marrakech Realty  ...
#
#   etage surface_terrain  prix_num  surface_num  chambres_num  salles_bain_num  \
# 0    -1             NaN   13000.0        120.0           2.0              1.0
# 1    -1             NaN   30000.0        355.0          10.0             12.0
# 2    -1             NaN    3600.0         35.0           0.0              0.0
# 3     0             NaN    9000.0          NaN           2.0              0.0
# 4     0             NaN   22000.0          NaN           0.0              0.0
#
#    nb_pieces        quartier     prix_m2  prix_m2_median_quartier
# 0        4.0           Autre  108.333333               125.595238
# 1       23.0  Route d'Ourika   84.507042                44.753521
# 2        1.0           Autre  102.857143                57.870370
# 3        3.0           Autre         NaN                57.870370
# 4        2.0           Autre         NaN                57.870370
#
# [5 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       110 non-null    str
#  1   titre                    151 non-null    str
#  2   prix                     93 non-null     str
#  3   localisation             152 non-null    str
#  4   type_bien                151 non-null    str
#  5   surface                  145 non-null    str
#  6   chambres                 145 non-null    str
#  7   salles_bain              56 non-null     str
#  8   description              62 non-null     str
#  9   agence                   111 non-null    str
#  10  url                      151 non-null    str
#  11  source                   152 non-null    str
#  12  piscine                  152 non-null    int64
#  13  parking                  152 non-null    int64
#  14  ascenseur                152 non-null    int64
#  15  terrasse                 152 non-null    int64
#  16  jardin                   152 non-null    int64
#  17  climatisation            152 non-null    int64
#  18  securite                 152 non-null    int64
#  19  vue                      152 non-null    int64
#  20  meuble                   152 non-null    int64
#  21  neuf                     152 non-null    int64
#  22  cave                     152 non-null    int64
#  23  hammam                   152 non-null    int64
#  24  etage                    152 non-null    int64
#  25  surface_terrain          0 non-null      float64
#  26  prix_num                 55 non-null     float64
#  27  surface_num              142 non-null    float64
#  28  chambres_num             152 non-null    float64
#  29  salles_bain_num          152 non-null    float64
#  30  nb_pieces                152 non-null    float64
#  31  quartier                 152 non-null    str
#  32  prix_m2                  51 non-null     float64
#  33  prix_m2_median_quartier  63 non-null     float64
# dtypes: float64(8), int64(13), str(13)
# memory usage: 40.5 KB

# %%
df.describe()
# Out:
#           piscine     parking   ascenseur    terrasse      jardin  \
# count  152.000000  152.000000  152.000000  152.000000  152.000000
# mean     0.236842    0.105263    0.006579    0.236842    0.125000
# std      0.426550    0.307907    0.081111    0.426550    0.331812
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000
#
#        climatisation    securite         vue      meuble        neuf  ...  \
# count     152.000000  152.000000  152.000000  152.000000  152.000000  ...
# mean        0.105263    0.006579    0.065789    0.203947    0.026316  ...
# std         0.307907    0.081111    0.248733    0.404262    0.160602  ...
# min         0.000000    0.000000    0.000000    0.000000    0.000000  ...
# 25%         0.000000    0.000000    0.000000    0.000000    0.000000  ...
# 50%         0.000000    0.000000    0.000000    0.000000    0.000000  ...
# 75%         0.000000    0.000000    0.000000    0.000000    0.000000  ...
# max         1.000000    1.000000    1.000000    1.000000    1.000000  ...
#
#            hammam       etage  surface_terrain       prix_num    surface_num  \
# count  152.000000  152.000000              0.0      55.000000     142.000000
# mean     0.052632   -0.960526              NaN   34600.909091    3519.211268
# std      0.224035    0.195363              NaN   56830.669937   33552.872473
# min      0.000000   -1.000000              NaN     500.000000       0.000000
# 25%      0.000000   -1.000000              NaN    8500.000000     152.500000
# 50%      0.000000   -1.000000              NaN   20000.000000     271.000000
# 75%      0.000000   -1.000000              NaN   32500.000000     497.500000
# max      1.000000    0.000000              NaN  350000.000000  400000.000000
#
#        chambres_num  salles_bain_num   nb_pieces      prix_m2  \
# count    152.000000       152.000000  152.000000    51.000000
# mean       5.572368         1.467105    8.052632   177.006654
# std        3.260443         2.449267    4.149187   400.121242
# min        0.000000         0.000000    1.000000     0.833333
# 25%        4.000000         0.000000    5.000000    21.000000
# 50%        5.000000         0.000000    7.000000    60.000000
# 75%        7.000000         3.000000   10.000000   126.237106
# max       18.000000        12.000000   25.000000  2187.500000
#
#        prix_m2_median_quartier
# count                63.000000
# mean                 72.246563
# std                  46.038971
# min                   0.833333
# 25%                  42.222222
# 50%                  60.000000
# 75%                 125.595238
# max                 178.571429
#
# [8 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['id', 'titre', 'prix', 'localisation', 'type_bien', 'surface',
#        'chambres', 'salles_bain', 'description', 'agence', 'url', 'source',
#        'piscine', 'parking', 'ascenseur', 'terrasse', 'jardin',
#        'climatisation', 'securite', 'vue', 'meuble', 'neuf', 'cave', 'hammam',
#        'etage', 'surface_terrain', 'prix_num', 'surface_num', 'chambres_num',
#        'salles_bain_num', 'nb_pieces', 'quartier', 'prix_m2',
#        'prix_m2_median_quartier'],
#       dtype='str')

# %%
df.shape
# Out:
# (152, 34)

# %% [markdown]
# ## 1. Target Protection & Deduplication
# We must drop rows without a price (target) and remove duplicates.

# %%
if 'df' in locals():
    # 1. Drop missing target
    if 'prix_num' in df.columns:
        initial_len = len(df)
        df = df.dropna(subset=['prix_num'])
        print(f"Dropped {initial_len - len(df)} rows with missing prix_num")
    
    # 2. Drop duplicates
    initial_len = len(df)
    df = df.drop_duplicates()
    print(f"Dropped {initial_len - len(df)} duplicate rows")
# Out:
# Dropped 0 rows with missing prix_num
# Dropped 0 duplicate rows

# %% [markdown]
# ## 2. Feature Selection & Data Leakage Prevention
# Drop non-predictive columns and columns that cause data leakage (like prix_m2).

# %%
if 'df' in locals():
    cols_to_drop = ['id', 'url', 'source', 'titre', 'description', 'prix', 'surface', 'localisation', 'chambres', 'salles_bain', 'surface_terrain']
    existing_drops = [c for c in cols_to_drop if c in df.columns]
    df = df.drop(columns=existing_drops)
    print(f"Dropped columns: {existing_drops}")
    print(f"Remaining columns: {df.columns.tolist()}")
# Out:
# Dropped columns: ['id', 'url', 'source', 'titre', 'description', 'prix', 'surface', 'localisation', 'chambres', 'salles_bain', 'surface_terrain']
# Remaining columns: ['type_bien', 'agence', 'piscine', 'parking', 'ascenseur', 'terrasse', 'jardin', 'climatisation', 'securite', 'vue', 'meuble', 'neuf', 'cave', 'hammam', 'etage', 'prix_num', 'surface_num', 'chambres_num', 'salles_bain_num', 'nb_pieces', 'quartier', 'prix_m2', 'prix_m2_median_quartier']

# %% [markdown]
# ## 3. Intelligent Imputation
# Handling missing values for features.

# %%
if 'df' in locals():
    # Missing values before
    print("Missing values before imputation:")
    print(df.isnull().sum()[df.isnull().sum() > 0])
    
    # 1. Numeric: Median
    if 'surface_num' in df.columns:
        df['surface_num'] = df['surface_num'].fillna(df['surface_num'].median())
    
        # 2. Rooms/Baths logic - Imputation par la moyenne au lieu de 0.0
for col in ['chambres_num', 'salles_bain_num']:
    if col in df.columns:
        # On remplace les 0 par NaN pour qu'ils soient imputés par la moyenne
        df[col] = df[col].replace(0, np.nan)
        # Remplissage par la moyenne (arrondie à l'entier le plus proche)
        df[col] = df[col].fillna(round(df[col].mean() if not df[col].isnull().all() else 1))


# 1b. Calcul du prix_m2 manquant à partir du prix_num et surface_num
if 'prix_m2' in df.columns and 'prix_num' in df.columns and 'surface_num' in df.columns:
    # On remplace temporairement les surfaces 0 par NaN pour éviter la division par zéro
    temp_surface = df['surface_num'].replace(0, np.nan)
    df['prix_m2'] = df['prix_m2'].fillna(df['prix_num'] / temp_surface)
  
    # 3. Categorical: Mode
    cat_cols = ['agence', 'type_bien', 'quartier']
    for col in cat_cols:
        if col in df.columns:
            df[col] = df[col].fillna(df[col].mode()[0] if not df[col].mode().empty else 'Inconnu')

    print("\nMissing values after imputation:")
    print(df.isnull().sum()[df.isnull().sum() > 0])
# Out:
# Missing values before imputation:
# agence                     32
# surface_num                 4
# prix_m2                     4
# prix_m2_median_quartier     1
# dtype: int64
#
# Missing values after imputation:
# prix_m2_median_quartier    1
# dtype: int64

# %%
df.dropna()
# Out:
#        type_bien                agence  piscine  parking  ascenseur  terrasse  \
# 0    Appartement                Yakeey        0        0          0         0
# 1    Appartement                Yakeey        0        0          0         0
# 2           Riad      Marrakech Realty        0        0          0         0
# 3           Riad      Marrakech Realty        0        0          0         1
# 4           Riad      Marrakech Realty        1        0          0         1
# 5           Riad      Marrakech Realty        1        1          0         1
# 94   Appartement           Particulier        0        0          0         0
# 95   Appartement           Particulier        0        1          0         0
# 96   Appartement           Particulier        0        0          0         0
# 97   Appartement           Particulier        0        0          0         0
# 98   Appartement           Particulier        0        0          0         0
# 99   Appartement           Particulier        0        0          0         0
# 100  Appartement           Particulier        0        0          0         0
# 101  Appartement           Particulier        0        0          0         0
# 102  Appartement           Particulier        0        0          0         0
# 103  Appartement           Particulier        0        0          0         1
# 104  Appartement           Particulier        0        0          0         1
# 105  Appartement           Particulier        0        0          0         0
# 106  Appartement           Particulier        0        0          0         0
# 108  Appartement           Particulier        1        0          0         0
# 109         Riad  Promo Immo Marrakech        1        0          0         1
# 110         Riad  Promo Immo Marrakech        0        0          0         1
# 112         Riad           Particulier        0        0          0         1
# 113         Riad           Particulier        0        0          0         0
# 114         Riad           Particulier        0        0          0         0
# 115         Riad           Particulier        0        0          0         1
# 116         Riad           Particulier        0        0          0         0
# 117         Riad           Particulier        0        0          0         0
# 118         Riad           Particulier        1        1          0         1
# 119         Riad           Particulier        1        0          0         1
# 120         Riad           Particulier        1        0          0         0
# 121         Riad           Particulier        0        0          0         0
# 122         Riad           Particulier        1        0          0         1
# 123         Riad           Particulier        1        1          0         1
# 124         Riad           Particulier        1        0          0         0
# 125         Riad           Particulier        1        1          0         1
# 129         Riad           Particulier        0        0          0         0
# 132         Riad           Particulier        1        1          0         1
# 133         Riad           Particulier        1        1          0         1
# 134         Riad           Particulier        0        0          0         1
# 135         Riad           Particulier        0        1          0         0
# 136         Riad           Particulier        1        0          0         0
# 137         Riad           Particulier        1        0          0         0
# 138         Riad           Particulier        1        1          0         1
# 139         Riad           Particulier        1        1          0         1
# 141         Riad           Particulier        1        0          0         1
# 142         Riad           Particulier        0        0          0         0
# 143         Riad           Particulier        1        1          0         0
# 144         Riad           Particulier        0        0          0         0
# 145         Riad           Particulier        1        1          0         0
# 146         Riad           Particulier        1        0          0         1
# 148         Riad           Particulier        1        1          0         1
# 149         Riad           Particulier        1        1          0         1
# 151         Riad           Particulier        1        0          0         0
#
#      jardin  climatisation  securite  vue  ...  prix_num  surface_num  \
# 0         0              0         0    0  ...   13000.0        120.0
# 1         0              0         0    0  ...   30000.0        355.0
# 2         0              0         0    0  ...    3600.0         35.0
# 3         0              0         0    1  ...    9000.0        211.0
# 4         0              1         0    1  ...   22000.0        211.0
# 5         1              0         0    1  ...   40000.0       1000.0
# 94        0              0         0    0  ...  150000.0      10000.0
# 95        0              0         0    0  ...  350000.0        160.0
# 96        0              0         0    0  ...   90000.0        180.0
# 97        0              0         0    0  ...   20000.0        140.0
# 98        0              0         0    0  ...   50000.0       1700.0
# 99        0              0         0    0  ...    8000.0         25.0
# 100       0              0         0    0  ...   40000.0        500.0
# 101       0              0         0    0  ...  175000.0        211.0
# 102       0              0         0    0  ...   40000.0        120.0
# 103       0              0         0    0  ...  160000.0        120.0
# 104       0              0         0    0  ...   15000.0        200.0
# 105       0              0         0    0  ...   20000.0        260.0
# 106       0              0         0    0  ...     500.0        100.0
# 108       0              0         0    0  ...     550.0        120.0
# 109       0              0         0    0  ...   50000.0        864.0
# 110       0              0         0    0  ...   12000.0        180.0
# 112       0              0         0    0  ...   35000.0        150.0
# 113       0              0         0    0  ...   30000.0        275.0
# 114       0              0         0    0  ...    3000.0          2.0
# 115       0              1         1    0  ...   20000.0        100.0
# 116       0              0         0    0  ...    1100.0         50.0
# 117       0              0         0    0  ...   30000.0        211.0
# 118       1              1         0    0  ...   17000.0        500.0
# 119       0              0         0    1  ...    2500.0        270.0
# 120       1              0         0    1  ...    2500.0       3000.0
# 121       0              0         0    0  ...   28000.0        194.0
# 122       1              1         0    1  ...   50000.0       6000.0
# 123       0              0         0    0  ...    9000.0        150.0
# 124       1              1         0    0  ...   12000.0        800.0
# 125       1              1         0    0  ...   18000.0        450.0
# 129       0              0         0    0  ...    9000.0        130.0
# 132       1              1         0    0  ...   25000.0        400.0
# 133       1              1         0    0  ...   23000.0        400.0
# 134       0              0         0    0  ...   15000.0         84.0
# 135       1              0         0    0  ...   30000.0        200.0
# 136       0              0         0    0  ...    6000.0        150.0
# 137       1              0         0    0  ...   60000.0       3000.0
# 138       1              1         0    0  ...   20000.0        400.0
# 139       1              1         0    0  ...   20000.0        450.0
# 141       1              1         0    0  ...   45000.0      10000.0
# 142       0              0         0    0  ...   30000.0        272.0
# 143       0              1         0    0  ...   12000.0        150.0
# 144       0              0         0    0  ...    2500.0        500.0
# 145       1              0         0    0  ...    1300.0        150.0
# 146       0              0         0    0  ...   22000.0      10500.0
# 148       1              1         0    0  ...    2000.0        500.0
# 149       1              1         0    0  ...   17000.0        500.0
# 151       0              0         0    0  ...    5000.0        200.0
#
#      chambres_num  salles_bain_num  nb_pieces             quartier  \
# 0             2.0              1.0        4.0                Autre
# 1            10.0             12.0       23.0       Route d'Ourika
# 2             5.0              4.0        1.0                Autre
# 3             2.0              4.0        3.0                Autre
# 4             5.0              4.0        2.0                Autre
# 5            10.0              4.0       11.0                Autre
# 94           10.0             10.0       21.0      Route d'Amizmiz
# 95            4.0              4.0        9.0                Autre
# 96            8.0              8.0       17.0                Autre
# 97            4.0              6.0       11.0                Autre
# 98            7.0              3.0       11.0                Autre
# 99            2.0              2.0        5.0                Autre
# 100           8.0              3.0       12.0                Autre
# 101           5.0              4.0        1.0                Autre
# 102           5.0              5.0       11.0                Autre
# 103          12.0             12.0       25.0                Autre
# 104           5.0              1.0        7.0                Autre
# 105           6.0              6.0       13.0                Autre
# 106           4.0              3.0        8.0       Route d'Ourika
# 108           3.0              3.0        7.0                Autre
# 109           7.0              4.0       11.0                Autre
# 110           2.0              4.0        3.0                Targa
# 112           6.0              6.0       13.0                Autre
# 113           6.0              2.0        9.0                Autre
# 114           6.0              2.0        9.0                Autre
# 115           3.0              3.0        7.0               Médina
# 116           2.0              2.0        5.0                Autre
# 117          10.0              2.0       13.0                Autre
# 118           3.0              3.0        7.0         Route de Fès
# 119           3.0              3.0        7.0            Palmeraie
# 120           5.0              7.0       13.0       Route d'Ourika
# 121           4.0              3.0        8.0  Route de Casablanca
# 122           7.0              2.0       10.0                Autre
# 123           3.0              4.0        8.0                Autre
# 124           5.0              6.0       12.0                Autre
# 125           3.0              3.0        7.0         Route de Fès
# 129           3.0              4.0        8.0                Autre
# 132           4.0              4.0        9.0         Route de Fès
# 133           4.0              4.0        9.0         Route de Fès
# 134           4.0              4.0        5.0               Médina
# 135           5.0              5.0       11.0            Palmeraie
# 136           3.0              3.0        7.0                Autre
# 137           5.0              4.0       10.0         Route de Fès
# 138           4.0              3.0        8.0         Route de Fès
# 139           4.0              4.0        9.0         Route de Fès
# 141           5.0              8.0       14.0                Autre
# 142           9.0              2.0       12.0               Médina
# 143           3.0              2.0        6.0                Autre
# 144           3.0              2.0        4.0               Guéliz
# 145           3.0              2.0        6.0            Palmeraie
# 146           3.0              4.0        8.0         Route de Fès
# 148           4.0              3.0        8.0  Route de Casablanca
# 149           4.0              2.0        7.0  Route de Casablanca
# 151           4.0              3.0        8.0                Autre
#
#          prix_m2  prix_m2_median_quartier  log_prix_num  log_surface_num
# 0     108.333333               125.595238      9.472782         4.795791
# 1      84.507042                44.753521     10.308986         5.874931
# 2     102.857143                57.870370      8.188967         3.583519
# 3      42.654028                57.870370      9.105091         5.356586
# 4     104.265403                57.870370      9.998843         5.356586
# 5      40.000000                57.870370     10.596660         6.908755
# 94     15.000000                15.000000     11.918397         9.210440
# 95   2187.500000               125.595238     12.765691         5.081404
# 96    500.000000               125.595238     11.407576         5.198497
# 97    142.857143               125.595238      9.903538         4.948760
# 98     29.411765               125.595238     10.819798         7.438972
# 99    320.000000               125.595238      8.987322         3.258097
# 100    80.000000               125.595238     10.596660         6.216606
# 101   829.383886               125.595238     12.072547         5.356586
# 102   333.333333               125.595238     10.596660         4.795791
# 103  1333.333333               125.595238     11.982935         4.795791
# 104    75.000000               125.595238      9.615872         5.303305
# 105    76.923077               125.595238      9.903538         5.564520
# 106     5.000000                44.753521      6.216606         4.615121
# 108     4.583333               125.595238      6.311735         4.795791
# 109    57.870370                57.870370     10.819798         6.762730
# 110    66.666667                66.666667      9.392745         5.198497
# 112   233.333333                60.000000     10.463132         5.017280
# 113   109.090909                60.000000     10.308986         5.620401
# 114  1500.000000                60.000000      8.006701         1.098612
# 115   200.000000               178.571429      9.903538         4.615121
# 116    22.000000                60.000000      7.003974         3.931826
# 117   142.180095                60.000000     10.308986         5.356586
# 118    34.000000                42.222222      9.741027         6.216606
# 119     9.259259                 9.259259      7.824446         5.602119
# 120     0.833333                 0.833333      7.824446         8.006701
# 121   144.329897                34.000000     10.239996         5.273000
# 122     8.333333                60.000000     10.819798         8.699681
# 123    60.000000                60.000000      9.105091         5.017280
# 124    15.000000                60.000000      9.392745         6.685861
# 125    40.000000                42.222222      9.798183         6.111467
# 129    69.230769                60.000000      9.105091         4.875197
# 132    62.500000                42.222222     10.126671         5.993961
# 133    57.500000                42.222222     10.043293         5.993961
# 134   178.571429               178.571429      9.615872         4.442651
# 135   150.000000                 9.259259     10.308986         5.303305
# 136    40.000000                60.000000      8.699681         5.017280
# 137    20.000000                42.222222     11.002117         8.006701
# 138    50.000000                42.222222      9.903538         5.993961
# 139    44.444444                42.222222      9.903538         6.111467
# 141     4.500000                60.000000     10.714440         9.210440
# 142   110.294118               178.571429     10.308986         5.609472
# 143    80.000000                60.000000      9.392745         5.017280
# 144     5.000000                 5.000000      7.824446         6.216606
# 145     8.666667                 9.259259      7.170888         5.017280
# 146     2.095238                42.222222      9.998843         9.259226
# 148     4.000000                34.000000      7.601402         6.216606
# 149    34.000000                34.000000      9.741027         6.216606
# 151    25.000000                60.000000      8.517393         5.303305
#
# [54 rows x 25 columns]

# %%
df.shape
# Out:
# (55, 25)

# %% [markdown]
# ## 4. Feature Engineering
# Applying log transformations to stabilize variance.

# %%
if 'df' in locals():
    if 'prix_num' in df.columns:
        df['log_prix_num'] = np.log1p(df['prix_num'])
        print("Created log_prix_num")
    
    if 'surface_num' in df.columns:
        df['log_surface_num'] = np.log1p(df['surface_num'])
        print("Created log_surface_num")
# Out:
# Created log_prix_num
# Created log_surface_num

# %% [markdown]
# ## 5. Outlier Detection & Removal
# Using 1st and 99th percentiles.

# %%
if 'df' in locals():
    for col in ['prix_num', 'surface_num']:
        if col in df.columns:
            q_low = df[col].quantile(0.01)
            q_hi  = df[col].quantile(0.99)
            df = df[(df[col] <= q_hi) & (df[col] >= q_low)]
            print(f"Filtered {col} between {q_low:.2f} and {q_hi:.2f}")
    
    print(f"Final shape: {df.shape}")
# Out:
# Filtered prix_num between 527.00 and 255500.00
# Filtered surface_num between 13.96 and 10240.00
# Final shape: (51, 25)

# %% [markdown]
# ## 6. Exporting ML-Ready Data

# %%
if 'df' in locals():
    output_dir = '../../data/cleaned_data/location'
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    output_path = os.path.join(output_dir, 'riad_location_cleaned.csv')
    df.to_csv(output_path, index=False)
    print(f"Success! ML-ready data saved to {output_path}")
# Out:
# Success! ML-ready data saved to ../../data/cleaned_data/location/riad_location_cleaned.csv
