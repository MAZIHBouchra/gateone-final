# %% [markdown]
# # Data Cleaning Perfect - Studio Location Marrakech
# This notebook implements the 'Perfect Cleaning' pipeline for Machine Learning preparation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# File path
file_path = '../../data/marrakech_immo_location/studio_location.csv'

# Load data
if os.path.exists(file_path):
    df = pd.read_csv(file_path)
    print(f"Successfully loaded {file_path}")
    print(f"Initial shape: {df.shape}")
    display(df.head())
else:
    print(f"ERROR: File not found at {file_path}")
# Out:
# Successfully loaded ../../data/marrakech_immo_location/studio_location.csv
# Initial shape: (40, 34)
#        id                                              titre  \
# 0  177494                       Appartement à louer à Gueliz
# 1  157226                       Appartement à louer à Gueliz
# 2  198491  Studio à louer 15 000 dh 50 m² - Guéliz -RAK-G...
# 3  184485  Studio à louer 7 500 dh 65 m² - Hivernage -LO2...
# 4  749079   Studio à louer 7 500 dh 45 m² - Guéliz -LOM25314
#
#                prix           localisation    type_bien surface chambres  \
# 0          8 000 DH      Gueliz, Marrakech  Appartement   53 m²        1
# 1          5 500 DH      Gueliz, Marrakech  Appartement   58 m²        1
# 2  15 000 DH / mois     Marrakech - Guéliz       Studio      50        1
# 3   7 500 DH / mois  Marrakech - Hivernage       Studio      65        1
# 4   7 500 DH / mois     Marrakech - Guéliz       Studio      45        1
#
#   salles_bain description  agence  ... etage surface_terrain  prix_num  \
# 0           1         NaN  Yakeey  ...    -1             NaN    8000.0
# 1           1         NaN  Yakeey  ...    -1             NaN    5500.0
# 2           1         NaN     NaN  ...    -1             NaN   15000.0
# 3           1         NaN     NaN  ...    -1             NaN    7500.0
# 4           1         NaN     NaN  ...    -1             NaN    7500.0
#
#    surface_num  chambres_num  salles_bain_num  nb_pieces   quartier  \
# 0         53.0           1.0              1.0        3.0     Guéliz
# 1         58.0           1.0              1.0        3.0     Guéliz
# 2         50.0           1.0              1.0        3.0     Guéliz
# 3         65.0           1.0              1.0        3.0  Hivernage
# 4         45.0           1.0              1.0        3.0     Guéliz
#
#       prix_m2  prix_m2_median_quartier
# 0  150.943396               122.885491
# 1   94.827586               122.885491
# 2  300.000000               166.666667
# 3  115.384615               115.384615
# 4  166.666667               166.666667
#
# [5 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       40 non-null     str
#  1   titre                    40 non-null     str
#  2   prix                     40 non-null     str
#  3   localisation             40 non-null     str
#  4   type_bien                40 non-null     str
#  5   surface                  24 non-null     str
#  6   chambres                 33 non-null     str
#  7   salles_bain              7 non-null      str
#  8   description              31 non-null     str
#  9   agence                   36 non-null     str
#  10  url                      40 non-null     str
#  11  source                   40 non-null     str
#  12  piscine                  40 non-null     int64
#  13  parking                  40 non-null     int64
#  14  ascenseur                40 non-null     int64
#  15  terrasse                 40 non-null     int64
#  16  jardin                   40 non-null     int64
#  17  climatisation            40 non-null     int64
#  18  securite                 40 non-null     int64
#  19  vue                      40 non-null     int64
#  20  meuble                   40 non-null     int64
#  21  neuf                     40 non-null     int64
#  22  cave                     40 non-null     int64
#  23  hammam                   40 non-null     int64
#  24  etage                    40 non-null     int64
#  25  surface_terrain          0 non-null      float64
#  26  prix_num                 40 non-null     float64
#  27  surface_num              24 non-null     float64
#  28  chambres_num             40 non-null     float64
#  29  salles_bain_num          40 non-null     float64
#  30  nb_pieces                40 non-null     float64
#  31  quartier                 40 non-null     str
#  32  prix_m2                  24 non-null     float64
#  33  prix_m2_median_quartier  40 non-null     float64
# dtypes: float64(8), int64(13), str(13)
# memory usage: 10.8 KB

# %%
df.describe()
# Out:
#         piscine    parking  ascenseur   terrasse     jardin  climatisation  \
# count  40.00000  40.000000  40.000000  40.000000  40.000000      40.000000
# mean    0.37500   0.575000   0.275000   0.075000   0.050000       0.100000
# std     0.49029   0.500641   0.452203   0.266747   0.220721       0.303822
# min     0.00000   0.000000   0.000000   0.000000   0.000000       0.000000
# 25%     0.00000   0.000000   0.000000   0.000000   0.000000       0.000000
# 50%     0.00000   1.000000   0.000000   0.000000   0.000000       0.000000
# 75%     1.00000   1.000000   1.000000   0.000000   0.000000       0.000000
# max     1.00000   1.000000   1.000000   1.000000   1.000000       1.000000
#
#         securite   vue     meuble  neuf  ...  hammam      etage  \
# count  40.000000  40.0  40.000000  40.0  ...    40.0  40.000000
# mean    0.125000   0.0   0.200000   0.0  ...     0.0  -0.800000
# std     0.334932   0.0   0.405096   0.0  ...     0.0   0.992278
# min     0.000000   0.0   0.000000   0.0  ...     0.0  -1.000000
# 25%     0.000000   0.0   0.000000   0.0  ...     0.0  -1.000000
# 50%     0.000000   0.0   0.000000   0.0  ...     0.0  -1.000000
# 75%     0.000000   0.0   0.000000   0.0  ...     0.0  -1.000000
# max     1.000000   0.0   1.000000   0.0  ...     0.0   5.000000
#
#        surface_terrain      prix_num  surface_num  chambres_num  \
# count              0.0     40.000000    24.000000     40.000000
# mean               NaN   6375.000000    55.041667      0.825000
# std                NaN   2341.569712     6.974981      0.384808
# min                NaN   2200.000000    42.000000      0.000000
# 25%                NaN   5000.000000    50.000000      1.000000
# 50%                NaN   6250.000000    55.500000      1.000000
# 75%                NaN   7500.000000    60.000000      1.000000
# max                NaN  15000.000000    65.000000      1.000000
#
#        salles_bain_num  nb_pieces     prix_m2  prix_m2_median_quartier
# count        40.000000  40.000000   24.000000                40.000000
# mean          0.175000   2.000000  126.796267               123.983560
# std           0.384808   0.599145   45.850327                15.904605
# min           0.000000   1.000000   62.500000                95.833333
# 25%           0.000000   2.000000  100.000000               114.166667
# 50%           0.000000   2.000000  121.538462               124.908425
# 75%           0.000000   2.000000  141.579861               124.908425
# max           1.000000   3.000000  300.000000               166.666667
#
# [8 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['id', 'titre', 'prix', 'localisation', 'type_bien', 'surface',
#        'chambres', 'salles_bain', 'description', 'agence', 'url', 'source',
#        'piscine', 'parking', 'ascenseur', 'terrasse', 'jardin',
#        'climatisation', 'securite', 'vue', 'meuble', 'neuf', 'cave', 'hammam',
#        'etage', 'surface_terrain', 'prix_num', 'surface_num', 'chambres_num',
#        'salles_bain_num', 'nb_pieces', 'quartier', 'prix_m2',
#        'prix_m2_median_quartier'],
#       dtype='str')

# %%
df.shape
# Out:
# (40, 34)

# %% [markdown]
# ## 1. Target Protection & Deduplication
# We must drop rows without a price (target) and remove duplicates.

# %%
if 'df' in locals():
    # 1. Drop missing target
    if 'prix_num' in df.columns:
        initial_len = len(df)
        df = df.dropna(subset=['prix_num'])
        print(f"Dropped {initial_len - len(df)} rows with missing prix_num")
    
    # 2. Drop duplicates
    initial_len = len(df)
    df = df.drop_duplicates()
    print(f"Dropped {initial_len - len(df)} duplicate rows")
# Out:
# Dropped 0 rows with missing prix_num
# Dropped 0 duplicate rows

# %%
# Conversion des prix en DH si nécessaire
if 'df' in locals():
    if 'prix' in df.columns and 'prix_num' in df.columns:
        # Taux de conversion approximatif (1 EUR = 10.8 MAD)
        EUR_TO_MAD = 10.8
        
        def convert_to_dh(row):
            price_str = str(row['prix']).lower() if pd.notna(row['prix']) else ''
            price_num = row['prix_num']
            
            # Si le prix contient l'euro et qu'on n'a pas encore une valeur en DH cohérente
            if '€' in price_str or 'eur' in price_str:
                import re
                # Extraire le montant en euro (souvent le premier nombre)
                nums = re.findall(r'\d+', price_str.replace(' ', '').replace(',', ''))
                if nums:
                    # Si c'est en euros, on multiplie par notre taux
                    euro_val = float(nums[0])
                    # On vérifie si price_num est déjà une conversion correcte (proche de euro_val * 10)
                    # Sinon on force la conversion
                    if pd.isna(price_num) or price_num < euro_val * 5:
                        return round(euro_val * EUR_TO_MAD)
            
            return price_num
            
        df['prix_num'] = df.apply(convert_to_dh, axis=1)
        print("Prix uniformisés en DH.")

# %% [markdown]
# ## 2. Feature Selection & Data Leakage Prevention
# Drop non-predictive columns and columns that cause data leakage (like prix_m2).

# %%
if 'df' in locals():
    cols_to_drop = ['id', 'url', 'source', 'titre', 'description', 'prix', 'surface', 'localisation', 'chambres', 'salles_bain', 'surface_terrain']
    existing_drops = [c for c in cols_to_drop if c in df.columns]
    df = df.drop(columns=existing_drops)
    print(f"Dropped columns: {existing_drops}")
    print(f"Remaining columns: {df.columns.tolist()}")
# Out:
# Dropped columns: ['id', 'url', 'source', 'titre', 'description', 'prix', 'surface', 'localisation', 'chambres', 'salles_bain', 'surface_terrain']
# Remaining columns: ['type_bien', 'agence', 'piscine', 'parking', 'ascenseur', 'terrasse', 'jardin', 'climatisation', 'securite', 'vue', 'meuble', 'neuf', 'cave', 'hammam', 'etage', 'prix_num', 'surface_num', 'chambres_num', 'salles_bain_num', 'nb_pieces', 'quartier', 'prix_m2', 'prix_m2_median_quartier']

# %% [markdown]
# ## 3. Intelligent Imputation
# Handling missing values for features.

# %%
if 'df' in locals():
    # Missing values before
    print("Missing values before imputation:")
    print(df.isnull().sum()[df.isnull().sum() > 0])
    
    # 1. Numeric: Median
    if 'surface_num' in df.columns:
        df['surface_num'] = df['surface_num'].fillna(df['surface_num'].median())
    
    # 2. Rooms/Baths logic
    non_residential = ['terrain', 'locaux', 'commercial', 'bureaux']
    if 'studio' in non_residential:
        if 'chambres_num' in df.columns: df['chambres_num'] = df['chambres_num'].fillna(0.0)
        if 'salles_bain_num' in df.columns: df['salles_bain_num'] = df['salles_bain_num'].fillna(0.0)
    else:
        if 'chambres_num' in df.columns: df['chambres_num'] = df['chambres_num'].fillna(round(df['chambres_num'].mean() if not df['chambres_num'].isnull().all() else 0))
        if 'salles_bain_num' in df.columns: df['salles_bain_num'] = df['salles_bain_num'].fillna(round(df['salles_bain_num'].mean() if not df['salles_bain_num'].isnull().all() else 0))
            
    # 3. Categorical: Mode
    cat_cols = ['agence', 'type_bien', 'quartier']
    for col in cat_cols:
        if col in df.columns:
            df[col] = df[col].fillna(df[col].mode()[0] if not df[col].mode().empty else 'Inconnu')

    print("\nMissing values after imputation:")
    print(df.isnull().sum()[df.isnull().sum() > 0])
# Out:
# Missing values before imputation:
# agence          4
# surface_num    16
# prix_m2        16
# dtype: int64
#
# Missing values after imputation:
# prix_m2    16
# dtype: int64

# %% [markdown]
# ## 4. Feature Engineering
# Applying log transformations to stabilize variance.

# %%
if 'df' in locals():
    if 'prix_num' in df.columns:
        df['log_prix_num'] = np.log1p(df['prix_num'])
        print("Created log_prix_num")
    
    if 'surface_num' in df.columns:
        df['log_surface_num'] = np.log1p(df['surface_num'])
        print("Created log_surface_num")
# Out:
# Created log_prix_num
# Created log_surface_num

# %% [markdown]
# ## 5. Outlier Detection & Removal
# Using 1st and 99th percentiles.

# %%
if 'df' in locals():
    for col in ['prix_num', 'surface_num']:
        if col in df.columns:
            q_low = df[col].quantile(0.01)
            q_hi  = df[col].quantile(0.99)
            df = df[(df[col] <= q_hi) & (df[col] >= q_low)]
            print(f"Filtered {col} between {q_low:.2f} and {q_hi:.2f}")
    
    print(f"Final shape: {df.shape}")
# Out:
# Filtered prix_num between 2512.00 and 13050.00
# Filtered surface_num between 43.11 and 65.00
# Final shape: (37, 25)

# %% [markdown]
# ## 6. Exporting ML-Ready Data

# %%
if 'df' in locals():
    output_dir = '../../data/cleaned_data/location'
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    output_path = os.path.join(output_dir, 'studio_location_cleaned.csv')
    df.to_csv(output_path, index=False)
    print(f"Success! ML-ready data saved to {output_path}")
# Out:
# Success! ML-ready data saved to ../../data/cleaned_data/location/studio_location_cleaned.csv
