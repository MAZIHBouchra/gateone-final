# %% [markdown]
# # Data Cleaning Perfect - Ferme Vente Marrakech
# This notebook implements the 'Perfect Cleaning' pipeline for Machine Learning preparation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# File path
file_path = '../../data/marrakech_immo_vente/ferme_vente.csv'

# Load data
if os.path.exists(file_path):
    df = pd.read_csv(file_path)
    print(f"Successfully loaded {file_path}")
    print(f"Initial shape: {df.shape}")
    display(df.head())
else:
    print(f"ERROR: File not found at {file_path}")
# Out:
# Successfully loaded ../../data/marrakech_immo_vente/ferme_vente.csv
# Initial shape: (58, 34)
#           id                                              titre          prix  \
# 0  8318102.0           Ferme à vendre – Route Ourika, Marrakech  4 500 000 DH
# 1  8281912.0      Ferme 2 hectares a vendre RT de Fès Marrakech  2 400 000 DH
# 2  8322499.0  Vente d un terrain avec une petite villa à lhaouz    120 000 DH
# 3  8277748.0       Ferme 3,57 H, km 24, route de Fes, Marrakech  3 900 000 DH
# 4  7651088.0    Ferme de 5 hectares titré en vente route de Fès  5 500 000 DH
#
#                    localisation type_bien   surface    chambres  salles_bain  \
# 0  Route de l'Ourika, Marrakech    Maison  18000 m²         NaN          NaN
# 1       Route de Fez, Marrakech    Maison    800 m²  4 Chambres          NaN
# 2  Route de l'Ourika, Marrakech    Maison   1500 m²         NaN          NaN
# 3       Route de Fez, Marrakech    Maison       NaN         NaN          NaN
# 4       Route de Fez, Marrakech    Maison  50000 m²         NaN          NaN
#
#                                          description       agence  ... etage  \
# 0  Superbe ferme titrée de 18 000 m² idéalement s...  Particulier  ...    -1
# 1  Belle ferme de 2 hectares titrée a vendre situ...  Particulier  ...     2
# 2  Ard fala7iya llbi3 b masaha 7awali 1500 m², me...  Particulier  ...    -1
# 3  À vendre, une très charmante ferme de 3,57 hec...  Particulier  ...    -1
# 4  Je vous propose une très belle ferme titrée de...  Particulier  ...    -1
#
#   surface_terrain   prix_num  surface_num  chambres_num  salles_bain_num  \
# 0             0.0  4500000.0      18000.0           0.0              0.0
# 1             NaN  2400000.0        800.0           4.0              0.0
# 2             NaN   120000.0       1500.0           0.0              0.0
# 3             NaN  3900000.0          NaN           0.0              0.0
# 4             NaN  5500000.0      50000.0           0.0              0.0
#
#    nb_pieces        quartier  prix_m2  prix_m2_median_quartier
# 0        1.0  Route d'Ourika    250.0               365.714286
# 1        5.0           Autre   3000.0               161.521260
# 2        1.0  Route d'Ourika     80.0               365.714286
# 3        1.0           Autre      NaN               161.521260
# 4        1.0           Autre    110.0               161.521260
#
# [5 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       57 non-null     float64
#  1   titre                    58 non-null     str
#  2   prix                     58 non-null     str
#  3   localisation             58 non-null     str
#  4   type_bien                58 non-null     str
#  5   surface                  54 non-null     str
#  6   chambres                 10 non-null     str
#  7   salles_bain              0 non-null      float64
#  8   description              58 non-null     str
#  9   agence                   58 non-null     str
#  10  url                      58 non-null     str
#  11  source                   58 non-null     str
#  12  piscine                  58 non-null     int64
#  13  parking                  58 non-null     int64
#  14  ascenseur                58 non-null     int64
#  15  terrasse                 58 non-null     int64
#  16  jardin                   58 non-null     int64
#  17  climatisation            58 non-null     int64
#  18  securite                 58 non-null     int64
#  19  vue                      58 non-null     int64
#  20  meuble                   58 non-null     int64
#  21  neuf                     58 non-null     int64
#  22  cave                     58 non-null     int64
#  23  hammam                   58 non-null     int64
#  24  etage                    58 non-null     int64
#  25  surface_terrain          1 non-null      float64
#  26  prix_num                 53 non-null     float64
#  27  surface_num              54 non-null     float64
#  28  chambres_num             58 non-null     float64
#  29  salles_bain_num          58 non-null     float64
#  30  nb_pieces                58 non-null     float64
#  31  quartier                 58 non-null     str
#  32  prix_m2                  50 non-null     float64
#  33  prix_m2_median_quartier  57 non-null     float64
# dtypes: float64(10), int64(13), str(11)
# memory usage: 15.5 KB

# %%
df.describe()
# Out:
#                  id  salles_bain    piscine    parking  ascenseur   terrasse  \
# count  5.700000e+01          0.0  58.000000  58.000000       58.0  58.000000
# mean   8.137415e+06          NaN   0.206897   0.086207        0.0   0.068966
# std    2.114078e+05          NaN   0.408619   0.283121        0.0   0.255609
# min    7.326176e+06          NaN   0.000000   0.000000        0.0   0.000000
# 25%    8.094196e+06          NaN   0.000000   0.000000        0.0   0.000000
# 50%    8.212439e+06          NaN   0.000000   0.000000        0.0   0.000000
# 75%    8.273558e+06          NaN   0.000000   0.000000        0.0   0.000000
# max    8.322499e+06          NaN   1.000000   1.000000        0.0   1.000000
#
#           jardin  climatisation   securite        vue  ...     hammam  \
# count  58.000000      58.000000  58.000000  58.000000  ...  58.000000
# mean    0.120690       0.017241   0.051724   0.086207  ...   0.017241
# std     0.328611       0.131306   0.223404   0.283121  ...   0.131306
# min     0.000000       0.000000   0.000000   0.000000  ...   0.000000
# 25%     0.000000       0.000000   0.000000   0.000000  ...   0.000000
# 50%     0.000000       0.000000   0.000000   0.000000  ...   0.000000
# 75%     0.000000       0.000000   0.000000   0.000000  ...   0.000000
# max     1.000000       1.000000   1.000000   1.000000  ...   1.000000
#
#            etage  surface_terrain      prix_num    surface_num  chambres_num  \
# count  58.000000              1.0  5.300000e+01      54.000000     58.000000
# mean   -0.862069              0.0  2.331000e+07   38192.259259      0.741379
# std     0.575776              NaN  1.370112e+08   73209.456155      1.782570
# min    -1.000000              0.0  1.200000e+05      20.000000      0.000000
# 25%    -1.000000              0.0  1.600000e+06    1500.000000      0.000000
# 50%    -1.000000              0.0  3.000000e+06    8800.000000      0.000000
# 75%    -1.000000              0.0  5.000000e+06   40000.000000      0.000000
# max     2.000000              0.0  1.000000e+09  320000.000000      8.000000
#
#        salles_bain_num  nb_pieces       prix_m2  prix_m2_median_quartier
# count             58.0  58.000000     50.000000                57.000000
# mean               0.0   1.741379   5151.075810               286.309764
# std                0.0   1.782570  12267.360376               331.022349
# min                0.0   1.000000      1.739130               161.521260
# 25%                0.0   1.000000    101.785714               161.521260
# 50%                0.0   1.000000    255.000000               161.521260
# 75%                0.0   1.000000   1251.380898               365.714286
# max                0.0   9.000000  57500.000000              1848.833145
#
# [8 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['id', 'titre', 'prix', 'localisation', 'type_bien', 'surface',
#        'chambres', 'salles_bain', 'description', 'agence', 'url', 'source',
#        'piscine', 'parking', 'ascenseur', 'terrasse', 'jardin',
#        'climatisation', 'securite', 'vue', 'meuble', 'neuf', 'cave', 'hammam',
#        'etage', 'surface_terrain', 'prix_num', 'surface_num', 'chambres_num',
#        'salles_bain_num', 'nb_pieces', 'quartier', 'prix_m2',
#        'prix_m2_median_quartier'],
#       dtype='str')

# %%
df.shape
# Out:
# (58, 34)

# %% [markdown]
# ## 1. Target Protection & Deduplication
# We must drop rows without a price (target) and remove duplicates.

# %%
if 'df' in locals():
    # 1. Drop missing target
    if 'prix_num' in df.columns:
        initial_len = len(df)
        df = df.dropna(subset=['prix_num'])
        print(f"Dropped {initial_len - len(df)} rows with missing prix_num")
    
    # 2. Drop duplicates
    initial_len = len(df)
    df = df.drop_duplicates()
    print(f"Dropped {initial_len - len(df)} duplicate rows")
# Out:
# Dropped 5 rows with missing prix_num
# Dropped 0 duplicate rows

# %%
# Conversion des prix en DH si nécessaire
if 'df' in locals():
    if 'prix' in df.columns and 'prix_num' in df.columns:
        # Taux de conversion approximatif (1 EUR = 10.8 MAD)
        EUR_TO_MAD = 10.8
        
        def convert_to_dh(row):
            price_str = str(row['prix']).lower() if pd.notna(row['prix']) else ''
            price_num = row['prix_num']
            
            # Si le prix contient l'euro et qu'on n'a pas encore une valeur en DH cohérente
            if '€' in price_str or 'eur' in price_str:
                import re
                # Extraire le montant en euro (souvent le premier nombre)
                nums = re.findall(r'\d+', price_str.replace(' ', '').replace(',', ''))
                if nums:
                    # Si c'est en euros, on multiplie par notre taux
                    euro_val = float(nums[0])
                    # On vérifie si price_num est déjà une conversion correcte (proche de euro_val * 10)
                    # Sinon on force la conversion
                    if pd.isna(price_num) or price_num < euro_val * 5:
                        return round(euro_val * EUR_TO_MAD)
            
            return price_num
            
        df['prix_num'] = df.apply(convert_to_dh, axis=1)
        print("Prix uniformisés en DH.")
# Out:
# Prix uniformisés en DH.

# %% [markdown]
# ## 2. Feature Selection & Data Leakage Prevention
# Drop non-predictive columns and columns that cause data leakage (like prix_m2).

# %%
if 'df' in locals():
    cols_to_drop = ['id', 'url', 'source', 'titre', 'description', 'prix', 'surface', 'localisation', 'chambres', 'salles_bain', 'prix_m2']
    existing_drops = [c for c in cols_to_drop if c in df.columns]
    df = df.drop(columns=existing_drops)
    print(f"Dropped columns: {existing_drops}")
    print(f"Remaining columns: {df.columns.tolist()}")
# Out:
# Dropped columns: ['id', 'url', 'source', 'titre', 'description', 'prix', 'surface', 'localisation', 'chambres', 'salles_bain', 'prix_m2']
# Remaining columns: ['type_bien', 'agence', 'piscine', 'parking', 'ascenseur', 'terrasse', 'jardin', 'climatisation', 'securite', 'vue', 'meuble', 'neuf', 'cave', 'hammam', 'etage', 'surface_terrain', 'prix_num', 'surface_num', 'chambres_num', 'salles_bain_num', 'nb_pieces', 'quartier', 'prix_m2_median_quartier']

# %% [markdown]
# ## 3. Intelligent Imputation
# Handling missing values for features.

# %%
if 'df' in locals():
    # Missing values before
    print("Missing values before imputation:")
    print(df.isnull().sum()[df.isnull().sum() > 0])
    
    # 1. Numeric: Median
    if 'surface_num' in df.columns:
        df['surface_num'] = df['surface_num'].fillna(df['surface_num'].median())
    
    # 2. Rooms/Baths logic - Imputation par la moyenne au lieu de 0.0
for col in ['chambres_num', 'salles_bain_num']:
    if col in df.columns:
        # On remplace les 0 par NaN pour qu'ils soient imputés par la moyenne
        df[col] = df[col].replace(0, np.nan)
        # Remplissage par la moyenne (arrondie à l'entier le plus proche)
        df[col] = df[col].fillna(round(df[col].mean() if not df[col].isnull().all() else 1))

# 1b. Calcul du prix_m2 manquant à partir du prix_num et surface_num
if 'prix_m2' in df.columns and 'prix_num' in df.columns and 'surface_num' in df.columns:
    # On remplace temporairement les surfaces 0 par NaN pour éviter la division par zéro
    temp_surface = df['surface_num'].replace(0, np.nan)
    df['prix_m2'] = df['prix_m2'].fillna(df['prix_num'] / temp_surface)
    # 3. Categorical: Mode
    cat_cols = ['agence', 'type_bien', 'quartier']
    for col in cat_cols:
        if col in df.columns:
            df[col] = df[col].fillna(df[col].mode()[0] if not df[col].mode().empty else 'Inconnu')

    print("\nMissing values after imputation:")
    print(df.isnull().sum()[df.isnull().sum() > 0])
# Out:
# Missing values before imputation:
# surface_terrain    52
# surface_num         3
# dtype: int64

# %% [markdown]
# ## 4. Feature Engineering
# Applying log transformations to stabilize variance.

# %%
if 'df' in locals():
    if 'prix_num' in df.columns:
        df['log_prix_num'] = np.log1p(df['prix_num'])
        print("Created log_prix_num")
    
    if 'surface_num' in df.columns:
        df['log_surface_num'] = np.log1p(df['surface_num'])
        print("Created log_surface_num")
# Out:
# Created log_prix_num
# Created log_surface_num

# %% [markdown]
# ## 5. Outlier Detection & Removal
# Using 1st and 99th percentiles.

# %%
if 'df' in locals():
    for col in ['prix_num', 'surface_num']:
        if col in df.columns:
            q_low = df[col].quantile(0.01)
            q_hi  = df[col].quantile(0.99)
            df = df[(df[col] <= q_hi) & (df[col] >= q_low)]
            print(f"Filtered {col} between {q_low:.2f} and {q_hi:.2f}")
    
    print(f"Final shape: {df.shape}")
# Out:
# Filtered prix_num between 239600.00 and 513280000.00
# Filtered surface_num between 27.50 and 280000.00
# Final shape: (49, 25)

# %% [markdown]
# ## 6. Exporting ML-Ready Data

# %%
if 'df' in locals():
    output_dir = '../../data/cleaned_data/vente'
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    output_path = os.path.join(output_dir, 'ferme_vente_cleaned.csv')
    df.to_csv(output_path, index=False)
    print(f"Success! ML-ready data saved to {output_path}")
# Out:
# Success! ML-ready data saved to ../../data/cleaned_data/vente/ferme_vente_cleaned.csv
