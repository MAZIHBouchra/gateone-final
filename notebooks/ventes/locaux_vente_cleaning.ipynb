# %% [markdown]
# # Data Cleaning Perfect - Locaux Vente Marrakech
# This notebook implements the 'Perfect Cleaning' pipeline for Machine Learning preparation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# File path
file_path = '../../data/marrakech_immo_vente/locaux_vente.csv'

# Load data
if os.path.exists(file_path):
    df = pd.read_csv(file_path)
    print(f"Successfully loaded {file_path}")
    print(f"Initial shape: {df.shape}")
    display(df.head())
else:
    print(f"ERROR: File not found at {file_path}")
# Out:
# Successfully loaded ../../data/marrakech_immo_vente/locaux_vente.csv
# Initial shape: (1292, 34)
#           id                                              titre  \
# 0  8239172.0  Local commercial à vendre à Sidi Ghanem. Surfa...
# 1  7677928.0           Magasin de 27m² en vente Dyour Al Masjid
# 2  8038230.0            Magasin 49 m² à louer à Semlalia Guéliz
# 3  8289761.0  Local commercial à vendre guéliz marrakech – e...
# 4  8320541.0  Vend local commercial à Agdal. Superficie 204 ...
#
#             prix            localisation type_bien surface chambres  \
# 0     500 000 DH  Sidi Ghanem, Marrakech    Maison  100 m²      NaN
# 1     405 000 DH       Mhamid, Marrakech    Maison   27 m²      NaN
# 2   1 250 000 DH       Guéliz, Marrakech    Maison   49 m²      NaN
# 3   3 990 000 DH       Guéliz, Marrakech    Maison  100 m²      NaN
# 4  36 000 000 DH        Agdal, Marrakech    Maison  204 m²      NaN
#
#           salles_bain description       agence  ... etage surface_terrain  \
# 0     1 Salle de bain         NaN  Particulier  ...    -1             NaN
# 1     1 Salle de bain         NaN  Particulier  ...    -1             NaN
# 2     1 Salle de bain         NaN  Particulier  ...    -1             NaN
# 3     1 Salle de bain         NaN  Particulier  ...    -1             NaN
# 4  16 Salles de bains         NaN  Particulier  ...    -1             NaN
#
#      prix_num  surface_num  chambres_num  salles_bain_num  nb_pieces  \
# 0    500000.0        100.0           0.0              1.0        2.0
# 1    405000.0         27.0           0.0              1.0        2.0
# 2   1250000.0         49.0           0.0              1.0        2.0
# 3   3990000.0        100.0           0.0              1.0        2.0
# 4  36000000.0        204.0           0.0             16.0       17.0
#
#    quartier        prix_m2  prix_m2_median_quartier
# 0     Autre    5000.000000             20301.177536
# 1   M'hamid   15000.000000             18055.555556
# 2    Guéliz   25510.204082             19000.000000
# 3    Guéliz   39900.000000             19000.000000
# 4     Agdal  176470.588235              8086.050415
#
# [5 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1292 entries, 0 to 1291
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       557 non-null    str
#  1   titre                    1292 non-null   str
#  2   prix                     1285 non-null   str
#  3   localisation             1292 non-null   str
#  4   type_bien                1292 non-null   str
#  5   surface                  1178 non-null   str
#  6   chambres                 147 non-null    str
#  7   salles_bain              836 non-null    str
#  8   description              862 non-null    str
#  9   agence                   522 non-null    str
#  10  url                      1292 non-null   str
#  11  source                   1292 non-null   str
#  12  piscine                  1292 non-null   int64
#  13  parking                  1292 non-null   int64
#  14  ascenseur                1292 non-null   int64
#  15  terrasse                 1292 non-null   int64
#  16  jardin                   1292 non-null   int64
#  17  climatisation            1292 non-null   int64
#  18  securite                 1292 non-null   int64
#  19  vue                      1292 non-null   int64
#  20  meuble                   1292 non-null   int64
#  21  neuf                     1292 non-null   int64
#  22  cave                     1292 non-null   int64
#  23  hammam                   1292 non-null   int64
#  24  etage                    1292 non-null   int64
#  25  surface_terrain          1 non-null      float64
#  26  prix_num                 1064 non-null   float64
#  27  surface_num              1139 non-null   float64
#  28  chambres_num             1292 non-null   float64
#  29  salles_bain_num          1292 non-null   float64
#  30  nb_pieces                1292 non-null   float64
#  31  quartier                 1292 non-null   str
#  32  prix_m2                  963 non-null    float64
#  33  prix_m2_median_quartier  1281 non-null   float64
# dtypes: float64(8), int64(13), str(13)
# memory usage: 343.3 KB

# %%
df.describe()
# Out:
#            piscine      parking    ascenseur     terrasse       jardin  \
# count  1292.000000  1292.000000  1292.000000  1292.000000  1292.000000
# mean      0.006966     0.030186     0.010836     0.073529     0.015480
# std       0.083203     0.171164     0.103570     0.261105     0.123499
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#        climatisation     securite          vue       meuble         neuf  ...  \
# count    1292.000000  1292.000000  1292.000000  1292.000000  1292.000000  ...
# mean        0.025542     0.010062     0.001548     0.070433     0.044118  ...
# std         0.157825     0.099842     0.039329     0.255975     0.205436  ...
# min         0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%         0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 50%         0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 75%         0.000000     0.000000     0.000000     0.000000     0.000000  ...
# max         1.000000     1.000000     1.000000     1.000000     1.000000  ...
#
#             hammam        etage  surface_terrain      prix_num    surface_num  \
# count  1292.000000  1292.000000              1.0  1.064000e+03    1139.000000
# mean      0.018576    -0.879257             46.0  1.011723e+07     929.172959
# std       0.135074     0.468334              NaN  1.668967e+08   14862.690687
# min       0.000000    -1.000000             46.0  1.000000e+00       2.000000
# 25%       0.000000    -1.000000             46.0  5.800000e+05      35.000000
# 50%       0.000000    -1.000000             46.0  1.290000e+06      76.000000
# 75%       0.000000    -1.000000             46.0  3.000000e+06     171.500000
# max       1.000000     5.000000             46.0  5.000004e+09  405000.000000
#
#        chambres_num  salles_bain_num    nb_pieces       prix_m2  \
# count   1292.000000      1292.000000  1292.000000  9.630000e+02
# mean       0.140093         0.945046     2.084365  3.363922e+05
# std        0.769099         2.178889     2.402523  6.832489e+06
# min        0.000000         0.000000     1.000000  3.311258e-03
# 25%        0.000000         0.000000     1.000000  1.065801e+04
# 50%        0.000000         1.000000     2.000000  1.863354e+04
# 75%        0.000000         1.000000     2.000000  2.750000e+04
# max       11.000000        58.000000    59.000000  1.666668e+08
#
#        prix_m2_median_quartier
# count              1281.000000
# mean              19052.964332
# std                6416.987202
# min                   0.020000
# 25%               19000.000000
# 50%               19285.714286
# 75%               19285.714286
# max               92380.952381
#
# [8 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['id', 'titre', 'prix', 'localisation', 'type_bien', 'surface',
#        'chambres', 'salles_bain', 'description', 'agence', 'url', 'source',
#        'piscine', 'parking', 'ascenseur', 'terrasse', 'jardin',
#        'climatisation', 'securite', 'vue', 'meuble', 'neuf', 'cave', 'hammam',
#        'etage', 'surface_terrain', 'prix_num', 'surface_num', 'chambres_num',
#        'salles_bain_num', 'nb_pieces', 'quartier', 'prix_m2',
#        'prix_m2_median_quartier'],
#       dtype='str')

# %%
df.shape
# Out:
# (1292, 34)

# %% [markdown]
# ## 1. Target Protection & Deduplication
# We must drop rows without a price (target) and remove duplicates.

# %%
if 'df' in locals():
    # 1. Drop missing target
    if 'prix_num' in df.columns:
        initial_len = len(df)
        df = df.dropna(subset=['prix_num'])
        print(f"Dropped {initial_len - len(df)} rows with missing prix_num")
    
    # 2. Drop duplicates
    initial_len = len(df)
    df = df.drop_duplicates()
    print(f"Dropped {initial_len - len(df)} duplicate rows")
# Out:
# Dropped 228 rows with missing prix_num
# Dropped 0 duplicate rows

# %%
# Conversion des prix en DH si nécessaire
if 'df' in locals():
    if 'prix' in df.columns and 'prix_num' in df.columns:
        # Taux de conversion approximatif (1 EUR = 10.8 MAD)
        EUR_TO_MAD = 10.8
        
        def convert_to_dh(row):
            price_str = str(row['prix']).lower() if pd.notna(row['prix']) else ''
            price_num = row['prix_num']
            
            # Si le prix contient l'euro et qu'on n'a pas encore une valeur en DH cohérente
            if '€' in price_str or 'eur' in price_str:
                import re
                # Extraire le montant en euro (souvent le premier nombre)
                nums = re.findall(r'\d+', price_str.replace(' ', '').replace(',', ''))
                if nums:
                    # Si c'est en euros, on multiplie par notre taux
                    euro_val = float(nums[0])
                    # On vérifie si price_num est déjà une conversion correcte (proche de euro_val * 10)
                    # Sinon on force la conversion
                    if pd.isna(price_num) or price_num < euro_val * 5:
                        return round(euro_val * EUR_TO_MAD)
            
            return price_num
            
        df['prix_num'] = df.apply(convert_to_dh, axis=1)
        print("Prix uniformisés en DH.")
# Out:
# Prix uniformisés en DH.

# %% [markdown]
# ## 2. Feature Selection & Data Leakage Prevention
# Drop non-predictive columns and columns that cause data leakage (like prix_m2).

# %%
if 'df' in locals():
    cols_to_drop = ['id', 'url', 'source', 'titre', 'description', 'prix', 'surface', 'localisation', 'chambres', 'salles_bain', 'surface_terrain']
    existing_drops = [c for c in cols_to_drop if c in df.columns]
    df = df.drop(columns=existing_drops)
    print(f"Dropped columns: {existing_drops}")
    print(f"Remaining columns: {df.columns.tolist()}")
# Out:
# Dropped columns: ['id', 'url', 'source', 'titre', 'description', 'prix', 'surface', 'localisation', 'chambres', 'salles_bain', 'surface_terrain']
# Remaining columns: ['type_bien', 'agence', 'piscine', 'parking', 'ascenseur', 'terrasse', 'jardin', 'climatisation', 'securite', 'vue', 'meuble', 'neuf', 'cave', 'hammam', 'etage', 'prix_num', 'surface_num', 'chambres_num', 'salles_bain_num', 'nb_pieces', 'quartier', 'prix_m2', 'prix_m2_median_quartier']

# %% [markdown]
# ## 3. Intelligent Imputation
# Handling missing values for features.

# %%
if 'df' in locals():
    # Missing values before
    print("Missing values before imputation:")
    print(df.isnull().sum()[df.isnull().sum() > 0])
    
    # 1. Numeric: Median
    if 'surface_num' in df.columns:
        df['surface_num'] = df['surface_num'].fillna(df['surface_num'].median())
    
    ## 2. Rooms/Baths logic - Imputation par la moyenne au lieu de 0.0
for col in ['chambres_num', 'salles_bain_num']:
    if col in df.columns:
        # On remplace les 0 par NaN pour qu'ils soient imputés par la moyenne
        df[col] = df[col].replace(0, np.nan)
        # Remplissage par la moyenne (arrondie à l'entier le plus proche)
        df[col] = df[col].fillna(round(df[col].mean() if not df[col].isnull().all() else 1))
        
# 1b. Calcul du prix_m2 manquant à partir du prix_num et surface_num
if 'prix_m2' in df.columns and 'prix_num' in df.columns and 'surface_num' in df.columns:
    # On remplace temporairement les surfaces 0 par NaN pour éviter la division par zéro
    temp_surface = df['surface_num'].replace(0, np.nan)
    df['prix_m2'] = df['prix_m2'].fillna(df['prix_num'] / temp_surface)

    # 3. Categorical: Mode
    cat_cols = ['agence', 'type_bien', 'quartier']
    for col in cat_cols:
        if col in df.columns:
            df[col] = df[col].fillna(df[col].mode()[0] if not df[col].mode().empty else 'Inconnu')

    print("\nMissing values after imputation:")
    print(df.isnull().sum()[df.isnull().sum() > 0])
# Out:
# Missing values before imputation:
# agence                     588
# surface_num                101
# prix_m2                    101
# prix_m2_median_quartier      1
# dtype: int64
#
# Missing values after imputation:
# prix_m2_median_quartier    1
# dtype: int64

# %%
df.dropna()
# Out:
#      type_bien       agence  piscine  parking  ascenseur  terrasse  jardin  \
# 0       Maison  Particulier        0        0          0         0       0
# 1       Maison  Particulier        0        0          0         0       0
# 2       Maison  Particulier        0        0          0         0       0
# 3       Maison  Particulier        0        0          0         0       0
# 4       Maison  Particulier        0        0          0         0       0
# ...        ...          ...      ...      ...        ...       ...     ...
# 1283    Locaux  Particulier        0        0          0         1       0
# 1284    Locaux  Particulier        0        0          0         0       0
# 1285    Locaux  Particulier        0        0          0         1       0
# 1289    Locaux  Particulier        0        0          0         0       0
# 1291    Locaux  Particulier        0        0          0         0       0
#
#       climatisation  securite  vue  ...  hammam  etage    prix_num  \
# 0                 0         0    0  ...       0     -1    500000.0
# 1                 0         0    0  ...       0     -1    405000.0
# 2                 0         0    0  ...       0     -1   1250000.0
# 3                 0         0    0  ...       0     -1   3990000.0
# 4                 0         0    0  ...       0     -1  36000000.0
# ...             ...       ...  ...  ...     ...    ...         ...
# 1283              0         0    0  ...       0     -1   2500000.0
# 1284              0         0    0  ...       0     -1   1800000.0
# 1285              0         0    0  ...       0     -1   3500000.0
# 1289              0         0    0  ...       0      0     35000.0
# 1291              0         0    0  ...       0     -1   1700000.0
#
#       surface_num  chambres_num  salles_bain_num  nb_pieces  quartier  \
# 0           100.0           3.0              1.0        2.0     Autre
# 1            27.0           3.0              1.0        2.0   M'hamid
# 2            49.0           3.0              1.0        2.0    Guéliz
# 3           100.0           3.0              1.0        2.0    Guéliz
# 4           204.0           3.0             16.0       17.0     Agdal
# ...           ...           ...              ...        ...       ...
# 1283         67.0           3.0              2.0        1.0     Autre
# 1284        312.0           3.0              3.0        4.0     Autre
# 1285        120.0           3.0              2.0        1.0     Autre
# 1289         68.0           3.0              1.0        2.0     Autre
# 1291        220.0           3.0              1.0        2.0     Autre
#
#             prix_m2  prix_m2_median_quartier
# 0       5000.000000             20301.177536
# 1      15000.000000             18055.555556
# 2      25510.204082             19000.000000
# 3      39900.000000             19000.000000
# 4     176470.588235              8086.050415
# ...             ...                      ...
# 1283   37313.432836             19285.714286
# 1284    5769.230769             19285.714286
# 1285   29166.666667             19285.714286
# 1289     514.705882             19285.714286
# 1291    7727.272727             19285.714286
#
# [1063 rows x 23 columns]

# %% [markdown]
# ## 4. Feature Engineering
# Applying log transformations to stabilize variance.

# %%
if 'df' in locals():
    if 'prix_num' in df.columns:
        df['log_prix_num'] = np.log1p(df['prix_num'])
        print("Created log_prix_num")
    
    if 'surface_num' in df.columns:
        df['log_surface_num'] = np.log1p(df['surface_num'])
        print("Created log_surface_num")
# Out:
# Created log_prix_num
# Created log_surface_num

# %% [markdown]
# ## 5. Outlier Detection & Removal
# Using 1st and 99th percentiles.

# %%
if 'df' in locals():
    for col in ['prix_num', 'surface_num']:
        if col in df.columns:
            q_low = df[col].quantile(0.01)
            q_hi  = df[col].quantile(0.99)
            df = df[(df[col] <= q_hi) & (df[col] >= q_low)]
            print(f"Filtered {col} between {q_low:.2f} and {q_hi:.2f}")
    
    print(f"Final shape: {df.shape}")
# Out:
# Filtered prix_num between 7760.00 and 33051600.00
# Filtered surface_num between 10.00 and 4931.00
# Final shape: (1022, 25)

# %% [markdown]
# ## 6. Exporting ML-Ready Data

# %%
if 'df' in locals():
    output_dir = '../../data/cleaned_data/vente'
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    output_path = os.path.join(output_dir, 'locaux_vente_cleaned.csv')
    df.to_csv(output_path, index=False)
    print(f"Success! ML-ready data saved to {output_path}")
# Out:
# Success! ML-ready data saved to ../../data/cleaned_data/vente/locaux_vente_cleaned.csv
