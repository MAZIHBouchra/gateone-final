# %% [markdown]
# # Data Cleaning Perfect - Maison Vente Marrakech
# This notebook implements the 'Perfect Cleaning' pipeline for Machine Learning preparation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# File path
file_path = '../../data/marrakech_immo_vente/maison_vente.csv'

# Load data
if os.path.exists(file_path):
    df = pd.read_csv(file_path)
    print(f"Successfully loaded {file_path}")
    print(f"Initial shape: {df.shape}")
    display(df.head())
else:
    print(f"ERROR: File not found at {file_path}")
# Out:
# Successfully loaded ../../data/marrakech_immo_vente/maison_vente.csv
# Initial shape: (1543, 34)
#           id                                              titre          prix  \
# 0  8300517.0    Maison d&rsquo; hôtes de 5 chambres / 2 bassins  6 500 000 DH
# 1  8192083.0                    Maison de ville à Vendre Guéliz   590 000 EUR
# 2  8316966.0           Bel maison à vendre 3 chambres Marrakech  1 740 000 DH
# 3  8289127.0  Maison à acheter à Ben Saleh 5min de la place ...   350 000 EUR
# 4  8324153.0                       Maison titré a vendre a azli  1 300 000 DH
#
#                       localisation type_bien surface    chambres  \
# 0               Assouel, Marrakech    Maison  250 m²  5 Chambres
# 1             Hivernage, Marrakech    Maison  400 m²  5 Chambres
# 2  Ennakhil (Palmeraie), Marrakech    Maison  142 m²  3 Chambres
# 3             Ben Saleh, Marrakech    Maison   80 m²  8 Chambres
# 4                  Azli, Marrakech    Maison  100 m²  3 Chambres
#
#          salles_bain description        agence  ... etage surface_terrain  \
# 0  5 Salles de bains         NaN   Particulier  ...    -1             NaN
# 1  4 Salles de bains         NaN  VANEAU MAROC  ...    -1             NaN
# 2  2 Salles de bains         NaN   Particulier  ...    -1             NaN
# 3  4 Salles de bains         NaN   Particulier  ...    -1             NaN
# 4  2 Salles de bains         NaN   Particulier  ...    -1             NaN
#
#     prix_num  surface_num  chambres_num  salles_bain_num  nb_pieces  \
# 0  6500000.0        250.0           5.0              5.0       11.0
# 1   590000.0        400.0           5.0              4.0       10.0
# 2  1740000.0        142.0           3.0              2.0        6.0
# 3   350000.0         80.0           8.0              4.0       13.0
# 4  1300000.0        100.0           3.0              2.0        6.0
#
#     quartier       prix_m2  prix_m2_median_quartier
# 0      Autre  26000.000000             14117.647059
# 1  Hivernage   1475.000000             10081.762295
# 2  Palmeraie  12253.521127             12253.521127
# 3      Autre   4375.000000             14117.647059
# 4      Autre  13000.000000             14117.647059
#
# [5 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1543 entries, 0 to 1542
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       487 non-null    str
#  1   titre                    1541 non-null   str
#  2   prix                     1533 non-null   str
#  3   localisation             1542 non-null   str
#  4   type_bien                1542 non-null   str
#  5   surface                  1509 non-null   str
#  6   chambres                 1453 non-null   str
#  7   salles_bain              1330 non-null   str
#  8   description              1131 non-null   str
#  9   agence                   471 non-null    str
#  10  url                      1542 non-null   str
#  11  source                   1543 non-null   str
#  12  piscine                  1543 non-null   int64
#  13  parking                  1543 non-null   int64
#  14  ascenseur                1543 non-null   int64
#  15  terrasse                 1543 non-null   int64
#  16  jardin                   1543 non-null   int64
#  17  climatisation            1543 non-null   int64
#  18  securite                 1543 non-null   int64
#  19  vue                      1543 non-null   int64
#  20  meuble                   1543 non-null   int64
#  21  neuf                     1543 non-null   int64
#  22  cave                     1543 non-null   int64
#  23  hammam                   1543 non-null   int64
#  24  etage                    1543 non-null   int64
#  25  surface_terrain          8 non-null      float64
#  26  prix_num                 1188 non-null   float64
#  27  surface_num              1504 non-null   float64
#  28  chambres_num             1543 non-null   float64
#  29  salles_bain_num          1543 non-null   float64
#  30  nb_pieces                1543 non-null   float64
#  31  quartier                 1543 non-null   str
#  32  prix_m2                  1160 non-null   float64
#  33  prix_m2_median_quartier  1537 non-null   float64
# dtypes: float64(8), int64(13), str(13)
# memory usage: 410.0 KB

# %%
df.describe()
# Out:
#            piscine      parking    ascenseur     terrasse       jardin  \
# count  1543.000000  1543.000000  1543.000000  1543.000000  1543.000000
# mean      0.055087     0.099806     0.001296     0.182761     0.072586
# std       0.228225     0.299838     0.035991     0.386596     0.259540
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#        climatisation     securite          vue       meuble         neuf  ...  \
# count    1543.000000  1543.000000  1543.000000  1543.000000  1543.000000  ...
# mean        0.023331     0.014906     0.020091     0.065457     0.014258  ...
# std         0.151002     0.121216     0.140356     0.247411     0.118591  ...
# min         0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%         0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 50%         0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 75%         0.000000     0.000000     0.000000     0.000000     0.000000  ...
# max         1.000000     1.000000     1.000000     1.000000     1.000000  ...
#
#             hammam        etage  surface_terrain      prix_num   surface_num  \
# count  1543.000000  1543.000000          8.00000  1.188000e+03   1504.000000
# mean      0.034349    -0.757615        204.12500  2.899015e+06    388.897606
# std       0.182182     0.710012        149.07758  1.224152e+07   2626.165035
# min       0.000000    -1.000000          1.00000  4.000000e+01      0.000000
# 25%       0.000000    -1.000000        105.50000  8.000000e+05     84.000000
# 50%       0.000000    -1.000000        220.00000  1.600000e+06    114.000000
# 75%       0.000000    -1.000000        312.50000  2.600000e+06    210.750000
# max       1.000000     3.000000        400.00000  3.000000e+08  70000.000000
#
#        chambres_num  salles_bain_num    nb_pieces       prix_m2  \
# count   1543.000000      1543.000000  1543.000000  1.160000e+03
# mean       4.432923         2.311730     7.665587  2.531254e+04
# std        2.683814         1.768924     3.974745  1.585491e+05
# min        0.000000         0.000000     1.000000  4.500000e-01
# 25%        3.000000         1.000000     5.000000  5.755495e+03
# 50%        4.000000         2.000000     7.000000  1.234651e+04
# 75%        6.000000         3.000000    10.000000  1.833333e+04
# max       34.000000        19.000000    52.000000  3.490000e+06
#
#        prix_m2_median_quartier
# count              1537.000000
# mean              11676.077165
# std                3079.229452
# min                5227.272727
# 25%               10303.030303
# 50%               10303.030303
# 75%               14117.647059
# max               25492.957746
#
# [8 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['id', 'titre', 'prix', 'localisation', 'type_bien', 'surface',
#        'chambres', 'salles_bain', 'description', 'agence', 'url', 'source',
#        'piscine', 'parking', 'ascenseur', 'terrasse', 'jardin',
#        'climatisation', 'securite', 'vue', 'meuble', 'neuf', 'cave', 'hammam',
#        'etage', 'surface_terrain', 'prix_num', 'surface_num', 'chambres_num',
#        'salles_bain_num', 'nb_pieces', 'quartier', 'prix_m2',
#        'prix_m2_median_quartier'],
#       dtype='str')

# %%
df.shape
# Out:
# (1543, 34)

# %% [markdown]
# ## 1. Target Protection & Deduplication
# We must drop rows without a price (target) and remove duplicates.

# %%
if 'df' in locals():
    # 1. Drop missing target
    if 'prix_num' in df.columns:
        initial_len = len(df)
        df = df.dropna(subset=['prix_num'])
        print(f"Dropped {initial_len - len(df)} rows with missing prix_num")
    
    # 2. Drop duplicates
    initial_len = len(df)
    df = df.drop_duplicates()
    print(f"Dropped {initial_len - len(df)} duplicate rows")
# Out:
# Dropped 355 rows with missing prix_num
# Dropped 0 duplicate rows

# %% [markdown]
# ## 2. Feature Selection & Data Leakage Prevention
# Drop non-predictive columns and columns that cause data leakage (like prix_m2).

# %%
if 'df' in locals():
    cols_to_drop = ['id', 'url', 'source', 'titre', 'description', 'prix', 'surface', 'localisation', 'chambres', 'salles_bain', 'surface_terrain']
    existing_drops = [c for c in cols_to_drop if c in df.columns]
    df = df.drop(columns=existing_drops)
    print(f"Dropped columns: {existing_drops}")
    print(f"Remaining columns: {df.columns.tolist()}")
# Out:
# Dropped columns: ['id', 'url', 'source', 'titre', 'description', 'prix', 'surface', 'localisation', 'chambres', 'salles_bain', 'surface_terrain']
# Remaining columns: ['type_bien', 'agence', 'piscine', 'parking', 'ascenseur', 'terrasse', 'jardin', 'climatisation', 'securite', 'vue', 'meuble', 'neuf', 'cave', 'hammam', 'etage', 'prix_num', 'surface_num', 'chambres_num', 'salles_bain_num', 'nb_pieces', 'quartier', 'prix_m2', 'prix_m2_median_quartier']

# %% [markdown]
# ## 3. Intelligent Imputation
# Handling missing values for features.

# %%
if 'df' in locals():
    # Missing values before
    print("Missing values before imputation:")
    print(df.isnull().sum()[df.isnull().sum() > 0])
    
    # 1. Numeric: Median
    if 'surface_num' in df.columns:
        df['surface_num'] = df['surface_num'].fillna(df['surface_num'].median())
    
    # 2. Rooms/Baths logic - Imputation par la moyenne au lieu de 0.0
for col in ['chambres_num', 'salles_bain_num']:
    if col in df.columns:
        # On remplace les 0 par NaN pour qu'ils soient imputés par la moyenne
        df[col] = df[col].replace(0, np.nan)
        # Remplissage par la moyenne (arrondie à l'entier le plus proche)
        df[col] = df[col].fillna(round(df[col].mean() if not df[col].isnull().all() else 1))

# 1b. Calcul du prix_m2 manquant à partir du prix_num et surface_num
if 'prix_m2' in df.columns and 'prix_num' in df.columns and 'surface_num' in df.columns:
    # On remplace temporairement les surfaces 0 par NaN pour éviter la division par zéro
    temp_surface = df['surface_num'].replace(0, np.nan)
    df['prix_m2'] = df['prix_m2'].fillna(df['prix_num'] / temp_surface)

    # 3. Categorical: Mode
    cat_cols = ['agence', 'type_bien', 'quartier']
    for col in cat_cols:
        if col in df.columns:
            df[col] = df[col].fillna(df[col].mode()[0] if not df[col].mode().empty else 'Inconnu')

    print("\nMissing values after imputation:")
    print(df.isnull().sum()[df.isnull().sum() > 0])
# Out:
# Missing values before imputation:
# agence         749
# surface_num     25
# prix_m2         28
# dtype: int64
#
# Missing values after imputation:
# prix_m2    3
# dtype: int64

# %%
df.dropna()
# Out:
#      type_bien        agence  piscine  parking  ascenseur  terrasse  jardin  \
# 0       Maison   Particulier        0        0          0         0       0
# 1       Maison  VANEAU MAROC        0        0          0         0       0
# 2       Maison   Particulier        0        0          0         0       0
# 3       Maison   Particulier        0        0          0         0       0
# 4       Maison   Particulier        0        0          0         0       0
# ...        ...           ...      ...      ...        ...       ...     ...
# 1534    Maison   Particulier        0        0          0         0       0
# 1535    Maison   Particulier        0        0          0         0       0
# 1539    Maison   Particulier        0        0          0         0       0
# 1540    Maison   Particulier        0        0          0         0       0
# 1541    Maison   Particulier        1        0          0         1       1
#
#       climatisation  securite  vue  ...  hammam  etage   prix_num  \
# 0                 0         0    0  ...       0     -1  6500000.0
# 1                 0         0    0  ...       0     -1   590000.0
# 2                 0         0    0  ...       0     -1  1740000.0
# 3                 0         0    0  ...       0     -1   350000.0
# 4                 0         0    0  ...       0     -1  1300000.0
# ...             ...       ...  ...  ...     ...    ...        ...
# 1534              0         0    0  ...       0     -1  6000000.0
# 1535              0         0    0  ...       0     -1  4000000.0
# 1539              0         0    0  ...       0     -1  1500000.0
# 1540              0         0    0  ...       0     -1  1300000.0
# 1541              1         0    0  ...       0      0  1800000.0
#
#       surface_num  chambres_num  salles_bain_num  nb_pieces        quartier  \
# 0           250.0           5.0              5.0       11.0           Autre
# 1           400.0           5.0              4.0       10.0       Hivernage
# 2           142.0           3.0              2.0        6.0       Palmeraie
# 3            80.0           8.0              4.0       13.0           Autre
# 4           100.0           3.0              2.0        6.0           Autre
# ...           ...           ...              ...        ...             ...
# 1534         74.0           4.0              1.0        6.0           Autre
# 1535        290.0           8.0              3.0       12.0           Autre
# 1539         96.0           8.0              4.0       13.0       Daoudiate
# 1540        100.0           5.0              4.0       10.0       Daoudiate
# 1541        200.0           5.0              3.0        9.0  Route d'Ourika
#
#            prix_m2  prix_m2_median_quartier
# 0     26000.000000             14117.647059
# 1      1475.000000             10081.762295
# 2     12253.521127             12253.521127
# 3      4375.000000             14117.647059
# 4     13000.000000             14117.647059
# ...            ...                      ...
# 1534  81081.081081             10303.030303
# 1535  13793.103448             10303.030303
# 1539  15625.000000             14886.363636
# 1540  13000.000000             14886.363636
# 1541   9000.000000              5714.285714
#
# [1185 rows x 23 columns]

# %% [markdown]
# ## 4. Feature Engineering
# Applying log transformations to stabilize variance.

# %%
if 'df' in locals():
    if 'prix_num' in df.columns:
        df['log_prix_num'] = np.log1p(df['prix_num'])
        print("Created log_prix_num")
    
    if 'surface_num' in df.columns:
        df['log_surface_num'] = np.log1p(df['surface_num'])
        print("Created log_surface_num")
# Out:
# Created log_prix_num
# Created log_surface_num

# %% [markdown]
# ## 5. Outlier Detection & Removal
# Using 1st and 99th percentiles.

# %%
if 'df' in locals():
    for col in ['prix_num', 'surface_num']:
        if col in df.columns:
            q_low = df[col].quantile(0.01)
            q_hi  = df[col].quantile(0.99)
            df = df[(df[col] <= q_hi) & (df[col] >= q_low)]
            print(f"Filtered {col} between {q_low:.2f} and {q_hi:.2f}")
    
    print(f"Final shape: {df.shape}")
# Out:
# Filtered prix_num between 1487.00 and 16369000.00
# Filtered surface_num between 36.00 and 4269.59
# Final shape: (1143, 25)

# %% [markdown]
# ## 6. Exporting ML-Ready Data

# %%
if 'df' in locals():
    output_dir = '../../data/cleaned_data/vente'
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    output_path = os.path.join(output_dir, 'maison_vente_cleaned.csv')
    df.to_csv(output_path, index=False)
    print(f"Success! ML-ready data saved to {output_path}")
# Out:
# Success! ML-ready data saved to ../../data/cleaned_data/vente/maison_vente_cleaned.csv
